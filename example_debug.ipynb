# %%
from src.run_config import run_config

config_filename = "config/bronx_sim_config.xml"
allow_write_output=True
compute_checksums=False 
do_print=True
printing_interval=0.01

# %%
from __future__ import annotations

from typing import Optional

from src.init_sim import init_sim
from src.write_sim_files import close_output_files, open_output_files, write_output_files


sim = init_sim(
    config_filename,
    allow_write_output = allow_write_output,
    compute_checksums = compute_checksums,
    do_print = do_print,
    seed = None,
)

# if sim.write_output:
#     open_output_files(sim)

# sim.simulate(do_print=do_print, printing_interval=printing_interval)

from src.init_dc import init_demand, init_demand_coverage

init_demand(sim, demand_filename="data/bronx/demand.csv")
# Out:
# reading sim data
# reading network tables
# building adjacency + shortest-path cache
# reading misc tables
# placing nodes in grid
# linking entities to nearest nodes
# initialising station stats
# initialising ambulance routes + sleep status

# %%
init_demand_coverage(sim)
# Out:
# test 0.0 Priority.HIGH
# demand set index 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/72/gsmssx6d0v585bc4x6z7cjqh0000gn/T/ipykernel_39580/2508991742.py in <module>
# ----> 1 init_demand_coverage(sim)
#
# ~/Desktop/EMS_Project/Ambulance/EMS-Simulation/src/init_dc.py in init_demand_coverage(sim, cover_times, raster_cell_num_rows, raster_cell_num_cols)
#     369             print('test', t, demand_priority)
#     370             pcm = get_points_coverage_mode_mut(sim, demand_priority, t)
# --> 371             dm = get_demand_mode(demand, demand_priority, t)
#     372             raster_index = dm.raster_index
#     373             if raster_index is None:
#
# ~/Desktop/EMS_Project/Ambulance/EMS-Simulation/src/init_dc.py in get_demand_mode(demand, priority, start_time)
#      63
#      64     print('demand set index', demand_set_index)
# ---> 65     demand_mode_index = demand.mode_lookup[demand_set_index][pr_col]
#      66     return demand.modes[demand_mode_index]
#      67
#
# IndexError: list index out of range

# %%
sim.demand.mode_lookup
# Out:
# [[1, 2, 3]]

# %%
sim.demand_coverage
